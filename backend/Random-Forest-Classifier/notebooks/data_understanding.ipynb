# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/ml_training_dataset.csv")

# %%
df.head()
# Out:
#    Application_ID  Age  Gender       City Employment_Type  Annual_Income  \
# 0         3000001   21  Female     Jaipur  Business Owner         631600
# 1         3000002   29    Male  Ahmedabad  Business Owner         644100
# 2         3000003   28  Female     Nashik        Salaried        1018600
# 3         3000004   30  Female     Nashik        Contract         901600
# 4         3000005   39    Male      Thane        Salaried        1270100
#
#    Employment_Duration_Years  Number_of_Dependents     Loan_Purpose  \
# 0                        8.0                     3  Home Renovation
# 1                       10.9                     3          Medical
# 2                        9.5                     1         Personal
# 3                        8.1                     3          Medical
# 4                        6.3                     0         Personal
#
#    Loan_Amount  ...  Previous_Defaults  Missed_Payments  \
# 0       263000  ...                  1                2
# 1       651000  ...                  0                0
# 2       913000  ...                  0                0
# 3       856000  ...                  0                0
# 4       463000  ...                  0                0
#
#    Maximum_Days_Past_Due  Recent_Credit_Enquiries  Credit_History_Length  \
# 0                     23                        3                    0.5
# 1                      0                        1                    7.7
# 2                      0                        3                    2.3
# 3                      0                        0                    4.3
# 4                      0                        4                   15.5
#
#    Number_of_Credit_Accounts  Payment_History  Credit_Score  Risk_Grade  \
# 0                          2            86.16           637           E
# 1                          3           100.00           698           D
# 2                          3           100.00           677           D
# 3                          4            99.66           699           D
# 4                          6           100.00           711           C
#
#    Decision
# 0    Reject
# 1   Approve
# 2   Approve
# 3    Reject
# 4   Approve
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (30000, 27)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Application_ID             30000 non-null  int64
#  1   Age                        30000 non-null  int64
#  2   Gender                     30000 non-null  str
#  3   City                       30000 non-null  str
#  4   Employment_Type            30000 non-null  str
#  5   Annual_Income              30000 non-null  int64
#  6   Employment_Duration_Years  30000 non-null  float64
#  7   Number_of_Dependents       30000 non-null  int64
#  8   Loan_Purpose               30000 non-null  str
#  9   Loan_Amount                30000 non-null  int64
#  10  Loan_Tenure_Months         30000 non-null  int64
#  11  Existing_Loans_Count       30000 non-null  int64
#  12  Total_Outstanding_Debt     30000 non-null  float64
#  13  Existing_Monthly_EMI       30000 non-null  float64
#  14  Debt_to_Income_Ratio       30000 non-null  float64
#  15  Loan_to_Income_Ratio       30000 non-null  float64
#  16  Credit_Utilization         30000 non-null  float64
#  17  Previous_Defaults          30000 non-null  int64
#  18  Missed_Payments            30000 non-null  int64
#  19  Maximum_Days_Past_Due      30000 non-null  int64
#  20  Recent_Credit_Enquiries    30000 non-null  int64
#  21  Credit_History_Length      30000 non-null  float64
#  22  Number_of_Credit_Accounts  30000 non-null  int64
#  23  Payment_History            30000 non-null  float64
#  24  Credit_Score               30000 non-null  int64
#  25  Risk_Grade                 30000 non-null  str
#  26  Decision                   30000 non-null  str
# dtypes: float64(8), int64(13), str(6)
# memory usage: 6.2 MB

# %%
df.isnull().sum()
# Out:
# Application_ID               0
# Age                          0
# Gender                       0
# City                         0
# Employment_Type              0
# Annual_Income                0
# Employment_Duration_Years    0
# Number_of_Dependents         0
# Loan_Purpose                 0
# Loan_Amount                  0
# Loan_Tenure_Months           0
# Existing_Loans_Count         0
# Total_Outstanding_Debt       0
# Existing_Monthly_EMI         0
# Debt_to_Income_Ratio         0
# Loan_to_Income_Ratio         0
# Credit_Utilization           0
# Previous_Defaults            0
# Missed_Payments              0
# Maximum_Days_Past_Due        0
# Recent_Credit_Enquiries      0
# Credit_History_Length        0
# Number_of_Credit_Accounts    0
# Payment_History              0
# Credit_Score                 0
# Risk_Grade                   0
# Decision                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Application_ID           Age  Annual_Income  Employment_Duration_Years  \
# count    3.000000e+04  30000.000000   3.000000e+04               30000.000000
# mean     3.015000e+06     36.048000   7.283103e+05                   5.590333
# std      8.660398e+03      8.207664   3.668370e+05                   3.029603
# min      3.000001e+06     21.000000   1.800000e+05                   0.500000
# 25%      3.007501e+06     30.000000   4.712750e+05                   3.400000
# 50%      3.015000e+06     36.000000   6.529000e+05                   5.500000
# 75%      3.022500e+06     42.000000   8.971000e+05                   7.700000
# max      3.030000e+06     65.000000   4.628500e+06                  18.500000
#
#        Number_of_Dependents   Loan_Amount  Loan_Tenure_Months  \
# count          30000.000000  3.000000e+04        30000.000000
# mean               1.589733  1.103774e+06           46.539600
# std                1.253821  8.021058e+05           19.795441
# min                0.000000  5.000000e+04           12.000000
# 25%                1.000000  5.110000e+05           36.000000
# 50%                1.000000  9.190000e+05           48.000000
# 75%                2.000000  1.475000e+06           60.000000
# max                6.000000  5.000000e+06           84.000000
#
#        Existing_Loans_Count  Total_Outstanding_Debt  Existing_Monthly_EMI  \
# count          30000.000000            3.000000e+04          30000.000000
# mean               0.910600            2.533139e+05           7594.149667
# std                1.035942            4.283075e+05          13138.868543
# min                0.000000            0.000000e+00              0.000000
# 25%                0.000000            0.000000e+00              0.000000
# 50%                1.000000            5.880000e+04           1660.000000
# 75%                2.000000            3.498250e+05          10390.000000
# max                4.000000            5.817200e+06         227120.000000
#
#        ...  Loan_to_Income_Ratio  Credit_Utilization  Previous_Defaults  \
# count  ...          30000.000000        30000.000000       30000.000000
# mean   ...            151.937148           31.903810           0.160467
# std    ...             73.519671           16.281996           0.400902
# min    ...             24.970000            1.000000           0.000000
# 25%    ...             88.540000           19.410000           0.000000
# 50%    ...            151.385000           30.030000           0.000000
# 75%    ...            215.890000           42.620000           0.000000
# max    ...            280.090000           96.200000           3.000000
#
#        Missed_Payments  Maximum_Days_Past_Due  Recent_Credit_Enquiries  \
# count     30000.000000           30000.000000             30000.000000
# mean          0.944900              10.885800                 2.410200
# std           1.142617              14.150532                 1.657577
# min           0.000000               0.000000                 0.000000
# 25%           0.000000               0.000000                 1.000000
# 50%           1.000000               8.000000                 2.000000
# 75%           1.000000              16.000000                 3.000000
# max          10.000000             153.000000                10.000000
#
#        Credit_History_Length  Number_of_Credit_Accounts  Payment_History  \
# count           30000.000000               30000.000000     30000.000000
# mean               12.428433                   3.914200        95.694776
# std                 8.437444                   1.749745         5.571274
# min                 0.500000                   1.000000        46.770000
# 25%                 5.600000                   3.000000        94.110000
# 50%                11.900000                   4.000000        97.530000
# 75%                18.300000                   5.000000       100.000000
# max                35.000000                  13.000000       100.000000
#
#        Credit_Score
# count  30000.000000
# mean     689.028967
# std       46.201007
# min      497.000000
# 25%      658.000000
# 50%      689.000000
# 75%      720.000000
# max      848.000000
#
# [8 rows x 21 columns]

# %%
categorical_cols = df.select_dtypes(include="object").columns
categorical_cols
# Out:
# C:\Users\svbad\AppData\Local\Temp\ipykernel_27260\3430876840.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include="object").columns
# Index(['Gender', 'City', 'Employment_Type', 'Loan_Purpose', 'Risk_Grade',
#        'Decision'],
#       dtype='str')

# %%
df["Decision"].value_counts()
# Out:
# Decision
# Reject     18583
# Approve    11417
# Name: count, dtype: int64

# %%
df["Decision"].value_counts(normalize=True) * 100
# Out:
# Decision
# Reject     61.943333
# Approve    38.056667
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x="Decision")

plt.title("Credit Decision Distribution")
plt.xlabel("Decision")
plt.ylabel("Number of Applications")
plt.show()

# %%
numeric_cols = df.select_dtypes(
    include=["int64", "float64"]
).columns

df[numeric_cols].hist(
    figsize=(18, 15),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    print(
        f"{col}: "
        f"min={df[col].min()}, "
        f"max={df[col].max()}"
    )
# Out:
# Application_ID: min=3000001, max=3030000
# Age: min=21, max=65
# Annual_Income: min=180000, max=4628500
# Employment_Duration_Years: min=0.5, max=18.5
# Number_of_Dependents: min=0, max=6
# Loan_Amount: min=50000, max=5000000
# Loan_Tenure_Months: min=12, max=84
# Existing_Loans_Count: min=0, max=4
# Total_Outstanding_Debt: min=0.0, max=5817200.0
# Existing_Monthly_EMI: min=0.0, max=227120.0
# Debt_to_Income_Ratio: min=5.0, max=95.0
# Loan_to_Income_Ratio: min=24.97, max=280.09
# Credit_Utilization: min=1.0, max=96.2
# Previous_Defaults: min=0, max=3
# Missed_Payments: min=0, max=10
# Maximum_Days_Past_Due: min=0, max=153
# Recent_Credit_Enquiries: min=0, max=10
# Credit_History_Length: min=0.5, max=35.0
# Number_of_Credit_Accounts: min=1, max=13
# Payment_History: min=46.77, max=100.0
# Credit_Score: min=497, max=848
